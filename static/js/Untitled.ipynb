# %%
import pandas as pd

# %%
L17json = \
[{"unique_key":"51672063","created_date":"2021-08-29T01:00:57.000","agency":"NYPD","agency_name":"New York City Police Department","complaint_type":"Noise - Residential","descriptor":"Loud Music/Party","location_type":"Residential Building/House","incident_zip":"10306","incident_address":"318 BURBANK AVENUE","street_name":"BURBANK AVENUE","cross_street_1":"CLAWSON STREET","cross_street_2":"HYLAN BOULEVARD","intersection_street_1":"CLAWSON STREET","intersection_street_2":"HYLAN BOULEVARD","city":"STATEN ISLAND","landmark":"BURBANK AVENUE","status":"In Progress","community_board":"02 STATEN ISLAND","bbl":"5036470053","borough":"STATEN ISLAND","x_coordinate_state_plane":"954020","y_coordinate_state_plane":"147875","open_data_channel_type":"ONLINE","park_facility_name":"Unspecified","park_borough":"STATEN ISLAND","latitude":"40.57250713462637","longitude":"-74.10881498015515","location":{"type":"Point","coordinates":[-74.10881498015515,40.57250713462637]},"location_address":"","location_city":"","location_state":"","location_zip":"",":@computed_region_efsh_h5xi":"10693",":@computed_region_f5dn_yrer":"30",":@computed_region_yeji_bk3q":"1",":@computed_region_92fq_4b7q":"14",":@computed_region_sbqj_enih":"76"}
,{"unique_key":"51668067","created_date":"2021-08-29T01:00:50.000","agency":"DOT","agency_name":"Department of Transportation","complaint_type":"Curb Condition","descriptor":"Broken Curb","location_type":"Sidewalk","incident_zip":"10308","incident_address":"110 ABINGDON AVENUE","street_name":"ABINGDON AVENUE","cross_street_1":"KATAN AVENUE","cross_street_2":"EAST FIGUREA AVENUE","intersection_street_1":"KATAN AVENUE","intersection_street_2":"EAST FIGUREA AVENUE","city":"STATEN ISLAND","landmark":"ABINGDON AVENUE","status":"In Progress","community_board":"03 STATEN ISLAND","bbl":"5054670049","borough":"STATEN ISLAND","x_coordinate_state_plane":"940656","y_coordinate_state_plane":"140528","open_data_channel_type":"MOBILE","park_facility_name":"Unspecified","park_borough":"STATEN ISLAND","latitude":"40.55228543226806","longitude":"-74.15687217683075","location":{"type":"Point","coordinates":[-74.15687217683075,40.55228543226806]},"location_address":"","location_city":"","location_state":"","location_zip":"",":@computed_region_efsh_h5xi":"10695",":@computed_region_f5dn_yrer":"15",":@computed_region_yeji_bk3q":"1",":@computed_region_92fq_4b7q":"9",":@computed_region_sbqj_enih":"76"}
,{"unique_key":"51664209","created_date":"2021-08-29T01:00:43.000","agency":"NYPD","agency_name":"New York City Police Department","complaint_type":"Noise - Residential","descriptor":"Banging/Pounding","location_type":"Residential Building/House","incident_zip":"10001","incident_address":"330 WEST   30 STREET","street_name":"WEST   30 STREET","cross_street_1":"8 AVENUE","cross_street_2":"9 AVENUE","intersection_street_1":"8 AVENUE","intersection_street_2":"9 AVENUE","city":"NEW YORK","landmark":"WEST   30 STREET","status":"In Progress","resolution_action_updated_date":"2021-08-29T05:04:13.000","community_board":"04 MANHATTAN","bbl":"1007530056","borough":"MANHATTAN","x_coordinate_state_plane":"985267","y_coordinate_state_plane":"212563","open_data_channel_type":"ONLINE","park_facility_name":"Unspecified","park_borough":"MANHATTAN","latitude":"40.75011282688794","longitude":"-73.99632947923503","location":{"type":"Point","coordinates":[-73.99632947923503,40.75011282688794]},"location_address":"","location_city":"","location_state":"","location_zip":"",":@computed_region_efsh_h5xi":"11722",":@computed_region_f5dn_yrer":"12",":@computed_region_yeji_bk3q":"4",":@computed_region_92fq_4b7q":"10",":@computed_region_sbqj_enih":"8"}
,{"unique_key":"51670653","created_date":"2021-08-29T01:00:40.000","agency":"NYPD","agency_name":"New York City Police Department","complaint_type":"Noise - Commercial","descriptor":"Loud Music/Party","location_type":"Club/Bar/Restaurant","incident_zip":"11106","incident_address":"31-11 BROADWAY","street_name":"BROADWAY","cross_street_1":"31 STREET","cross_street_2":"32 STREET","intersection_street_1":"31 STREET","intersection_street_2":"32 STREET","city":"ASTORIA","landmark":"BROADWAY","status":"In Progress","community_board":"01 QUEENS","bbl":"4006130001","borough":"QUEENS","x_coordinate_state_plane":"1004971","y_coordinate_state_plane":"216865","open_data_channel_type":"ONLINE","park_facility_name":"Unspecified","park_borough":"QUEENS","latitude":"40.76189649750308","longitude":"-73.92520125288917","location":{"type":"Point","coordinates":[-73.92520125288917,40.76189649750308]},"location_address":"","location_city":"","location_state":"","location_zip":"",":@computed_region_efsh_h5xi":"16863",":@computed_region_f5dn_yrer":"39",":@computed_region_yeji_bk3q":"3",":@computed_region_92fq_4b7q":"4",":@computed_region_sbqj_enih":"72"}]

# %%
L17_df = pd.DataFrame(L17json)
L17_df
# Out:
#   unique_key             created_date agency                      agency_name  \
# 0   51672063  2021-08-29T01:00:57.000   NYPD  New York City Police Department
# 1   51668067  2021-08-29T01:00:50.000    DOT     Department of Transportation
# 2   51664209  2021-08-29T01:00:43.000   NYPD  New York City Police Department
# 3   51670653  2021-08-29T01:00:40.000   NYPD  New York City Police Department
#
#         complaint_type        descriptor               location_type  \
# 0  Noise - Residential  Loud Music/Party  Residential Building/House
# 1       Curb Condition       Broken Curb                    Sidewalk
# 2  Noise - Residential  Banging/Pounding  Residential Building/House
# 3   Noise - Commercial  Loud Music/Party         Club/Bar/Restaurant
#
#   incident_zip      incident_address       street_name  ... location_address  \
# 0        10306    318 BURBANK AVENUE    BURBANK AVENUE  ...
# 1        10308   110 ABINGDON AVENUE   ABINGDON AVENUE  ...
# ...
